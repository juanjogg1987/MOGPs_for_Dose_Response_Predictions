# %% [markdown]
# ## Get Pubchem drug feautures

# %% [markdown]
# 1. finding corresponding Pubchem ids for the drugs
# 2. call Pubchem to get chemical properties of the drugs
# 3. Preprocess text Drug description from the original datasets
# 4. Preprocess some text characteristics from PubChem properties

# %%
import pandas as pd
import numpy as np
import os
#pip install PubChemPy
import pubchempy as pcp
import re
from pubchempy import Compound
import warnings
warnings.filterwarnings("ignore")
import time
import tqdm

# %%
# from GDSC database
drug_features = pd.read_csv("GDSC2_drug_features.csv")
drug_features.set_index("DRUG_ID", inplace= True)
drug_features.head()
# Out:
#           Drug_Name        Target        Target_Pathway   PubChem
# DRUG_ID
# 1834         743380             -          Unclassified         -
# 1854          MN-64  TNKS1, TNKS2         WNT signaling   2802462
# 1909     Venetoclax          BCL2  Apoptosis regulation  49846579
# 1913       AGI-5198  IDH1 (R132H)            Metabolism  56645356
# 1915        AZD3759          EGFR        EGFR signaling  78209992

# %% [markdown]
# ## Part 1: Get drug features from PubChempy

# %%
# %%time

for drug_id in drug_features.index: 
    drug_name = drug_features.loc[drug_id, "Drug_Name"]
    deriv = pcp.get_compounds(drug_name, 'name')
    drug_features.loc[drug_id, "deriv_found"] = len(deriv)
    try:
        drug_features.loc[drug_id, "PubChem_ID"]= re.findall(r'\((.*?)\)', str(deriv))
    except:
        if len(deriv)>1:
            drug_features.loc[drug_id, "PubChem_ID"]= str([np.int(x) for x in re.findall(r'\((.*?)\)', str(deriv))]).strip("[").strip("]")
        else:
            drug_features.loc[drug_id, "PubChem_ID"]= 0
# Out:
# CPU times: user 8.23 s, sys: 1.19 s, total: 9.42 s
# Wall time: 7min 41s

# %%
drug_features.to_csv("GDSC2_drug_features_PubChem.csv", index=False)

# %% [markdown]
# ### Manual matching for drugs with missing or mutiple data

# %%
# example
error_names_dict={"Lestauritinib": "Lestaurtinib"}
error_name = "Lestauritinib"

# correct the search results
error_drug_index = drug_features[drug_features["Drug_Name"]==error_name].index
correct_drug_name = error_names_dict[error_name]
drug_features.loc[error_drug_index, "Drug_Name"] = correct_drug_name

# %%
manual_corrections = {
    "Bleomycin (50 uM)":{"pubchem_id" : 5460769,
               "reference" : "https://www.cancerrxgene.org/compounds"},
    
    "Picolinici-acid": {"pubchem_id" : 1018,
               "reference" : "https://www.cancerrxgene.org/compounds"},
    
    "Nutlin-3a (-)": {"pubchem_id" : 11433190 ,
               "reference" : "https://www.cancerrxgene.org/compounds"},
    
    "KRAS (G12C) Inhibitor-12" : {"pubchem_id" : 73555129,
               "reference" : "https://www.cancerrxgene.org/compounds"},
    
    "BMS-345541": {"pubchem_id" : 9926054,
               "reference" : "https://www.cancerrxgene.org/compounds"},
    
    "Staurosporine": {"pubchem_id" : 44259,
               "reference" : "https://pubchem.ncbi.nlm.nih.gov/compound/44259"},
    
    "GW441756": {"pubchem_id" : 9943465,
               "reference" : "https://www.cancerrxgene.org/compounds"},
    
    "EHT-1864": {"pubchem_id" : 9938202,
               "reference" : "https://www.cancerrxgene.org/compounds"},
    
    "GSK-LSD1": { "pubchem_id": 71522234, 
                  "reference": "https://pubchem.ncbi.nlm.nih.gov/compound/71522234" },
    
    "MK-8776": { "pubchem_id": 16224745, 
                         "reference": "https://www.cancerrxgene.org/compounds"},
    
    "SL0101": {"pubchem_id": 10459196, 
                   "reference": "https://www.cancerrxgene.org/compounds"},
    
    "BIBR-1532": {"pubchem_id": 9927531, 
                "reference": "https://www.cancerrxgene.org/compounds"},
    
    "Dacarbazine": { "pubchem_id": 135398738, 
                   "reference": "https://pubchem.ncbi.nlm.nih.gov/compound/135398738"},
    
    "Sinularin": {"pubchem_id": 5477029, 
                  "reference": "https://pubchem.ncbi.nlm.nih.gov/compound/5477029"},
    
    "Bleomycin": {"pubchem_id": 5360373, 
                  "reference": "https://pubchem.ncbi.nlm.nih.gov/compound/Bleomycin"},
    
    "Dihydrorotenone": { "pubchem_id": 243725, 
                        "reference": "https://pubchem.ncbi.nlm.nih.gov/compound/243725"},
    
    "Vinorelbine": { "pubchem_id": 5311497, 
               "reference": "https://www.cancerrxgene.org/compounds"},
    
    "Vinblastine": {"pubchem_id": 6710780, 
                   "reference": "https://www.cancerrxgene.org/compounds"},
    
    "Obatoclax Mesylate": { "pubchem_id": 16681698, 
                   "reference": "https://pubchem.ncbi.nlm.nih.gov/compound/16681698"},
    
    "Vincristine" : {"pubchem_id": 5978, 
                   "reference": "https://pubchem.ncbi.nlm.nih.gov/compound/5978"},
    
    "Romidepsin": {"pubchem_id": 3425, 
                   "reference": "https://pubchem.ncbi.nlm.nih.gov/compound/Romidepsin"},
    
    "Temsirolimus": {"pubchem_id": 6918289, 
                   "reference": "https://www.cancerrxgene.org/compounds"},
    
    "Bleomycin": {"pubchem_id": 5360373, 
                   "reference": "https://www.drugbank.ca/drugs/DB00290"},
    
    "Vinblastine": {"pubchem_id": 13342, 
                   "reference": "https://www.drugbank.ca/drugs/DB00570"},
    
    
    "THZ-2-102-1" : {"pubchem_id": 146011539, 
                   "reference": "Katjusa Koler's suggestion"},
    
    "THZ-2-49" : {"pubchem_id": 78357763 , 
                   "reference": ["https://www.cancerrxgene.org/compounds", 
                                "https://www.medchemexpress.com/THZ2.html",
                                "https://pubchem.ncbi.nlm.nih.gov/compound/78357763"]},
    
    "QL-XII-47": {"pubchem_id": 71748056, 
                   "reference": "https://lincs.hms.harvard.edu/db/sm/10077-101-1/"},
    
    "BMS-345541" : {"pubchem_id": 9813758, 
                   "reference": ""},
    
    "Temsirolimus" : {"pubchem_id": 23724530, 
                   "reference": "https://www.drugbank.ca/drugs/DB06287"},
           
    }
    

for drug_name in manual_corrections:
    drug_index = drug_features[drug_features["Drug_Name"]==drug_name].index
    drug_features.loc[drug_index, "deriv_found"] = 1
    drug_features.loc[drug_index, "PubChem_ID"]= manual_corrections[drug_name]["pubchem_id"]

# %%
drugs_with_pubchem_id = drug_features[drug_features["PubChem_ID"]!=0].index
print("All drugs: %d, With known PubChem_Id: %d" % (drug_features.shape[0], len(drugs_with_pubchem_id)))
#54 without known PubChem_Id
# Out:
# All drugs: 297, With known PubChem_Id: 243

# %%
with open("drugs_with_pubchem_id_NEW.txt", 'w') as f:
    for s in drugs_with_pubchem_id:
        f.write(str(s) + '\n')

# %% [markdown]
# ## Getting properties by PubChem API

# %%
# %%time
# for i, PubChem_id in tqdm(list(enumerate(drug_features["PubChem_ID"].values))):
for count,PubChem_id in enumerate(drug_features["PubChem_ID"]):
    print(PubChem_id)
    try:
        #drug_index = drug_features[drug_features["PubChem_ID"]==PubChem_id].index
        drug_index = drug_features["PubChem_ID"][count:count+1].index
        #print((drug_features["PubChem_ID"]==PubChem_id).sum())
        print(PubChem_id)
        print(drug_index)
        
        c = Compound.from_cid(PubChem_id)
        #print(c.molecular_weight)
        
        drug_features.loc[drug_index, "molecular_weight"] = c.molecular_weight
        #print(drug_features.loc[drug_index, "molecular_weight"])
        #break
        drug_features.loc[drug_index, "elements"] = str(set(c.elements)).strip("{").strip("}")
        
        bonds = [int(str(i).split(",")[-1].strip(")")) for i in c.bonds]
        drug_features.loc[drug_index, "2bonds"] = bonds.count(2)
        drug_features.loc[drug_index, "3bonds"] = bonds.count(3)

        drug_features.loc[drug_index, "xlogp"] = c.xlogp
        drug_features.loc[drug_index, "formal_charge"] = c.charge
    
        drug_features.loc[drug_index, "surface_area"] = c.tpsa

        drug_features.loc[drug_index, "complexity"] = c.complexity

        drug_features.loc[drug_index, "h_bond_donor_count"] = c.h_bond_donor_count

        drug_features.loc[drug_index, "h_bond_acceptor_count"] = c.h_bond_acceptor_count

        drug_features.loc[drug_index, "rotatable_bond_count"] = c.rotatable_bond_count

        drug_features.loc[drug_index, "heavy_atom_count"] = c.heavy_atom_count

        drug_features.loc[drug_index, "atom_stereo_count"] = c.atom_stereo_count

        drug_features.loc[drug_index, "defined_atom_stereo_count"] = c.defined_atom_stereo_count

        drug_features.loc[drug_index, "undefined_atom_stereo_count"] = c.undefined_atom_stereo_count

        drug_features.loc[drug_index, "bond_stereo_count"] = c.bond_stereo_count

        drug_features.loc[drug_index, "covalent_unit_count"] = c.covalent_unit_count
        drug_features.loc[drug_index, "molecular_formula"] = c.molecular_formula

        drug_features.loc[drug_index, "canonical_smiles"] = c.canonical_smiles

        drug_features.loc[drug_index, "inchi_string"] = c.inchi

        drug_features.loc[drug_index, "inchi_key"] = c.inchikey
        #print(drug_features.head(15))
        #print(drug_features.loc[drug_index, "molecular_weight"])
        #break
    except:
        print("Weid stuff")
        #break
        pass

# # fingerprint
# # Raw padded and hex-encoded fingerprint, as returned by the PUG REST API.

# # cactvs_fingerprint
# # PubChem CACTVS fingerprint.
# # Each bit in the fingerprint represents the presence or absence of one of 881 chemical substructures.
# # More information at ftp://ftp.ncbi.nlm.nih.gov/pubchem/specifications/pubchem_fingerprints.txt
# Out:
# 0.0
# 0.0
# Int64Index([1834], dtype='int64', name='DRUG_ID')
# Weid stuff
# ['2802462']
# ['2802462']
# Int64Index([1854], dtype='int64', name='DRUG_ID')
# ['49846579']
# ['49846579']
# Int64Index([1909], dtype='int64', name='DRUG_ID')
# ['56645356']
# ['56645356']
# Int64Index([1913], dtype='int64', name='DRUG_ID')
# ['78209992']
# ['78209992']
# Int64Index([1915], dtype='int64', name='DRUG_ID')
# ['9825149']
# ['9825149']
# Int64Index([1932], dtype='int64', name='DRUG_ID')
# ['46931953']
# ['46931953']
# Int64Index([1933], dtype='int64', name='DRUG_ID')
# ['71297207']
# ['71297207']
# Int64Index([1997], dtype='int64', name='DRUG_ID')
# 0
# 0
# Int64Index([2011], dtype='int64', name='DRUG_ID')
# Weid stuff
# ['46224516']
# ['46224516']
# Int64Index([2038], dtype='int64', name='DRUG_ID')
# ['42642645']
# ['42642645']
# Int64Index([2040], dtype='int64', name='DRUG_ID')
# ['5284616']
# ['5284616']
# Int64Index([1084], dtype='int64', name='DRUG_ID')
# ['52918385']
# ['52918385']
# Int64Index([1131], dtype='int64', name='DRUG_ID')
# ['135565082']
# ['135565082']
# Int64Index([1259], dtype='int64', name='DRUG_ID')
# ['11707110']
# ['11707110']
# Int64Index([1372], dtype='int64', name='DRUG_ID')
# ['135539077']
# ['135539077']
# Int64Index([1559], dtype='int64', name='DRUG_ID')
# 5360373
# 5360373
# Int64Index([1812], dtype='int64', name='DRUG_ID')
# 3425
# 3425
# Int64Index([1817], dtype='int64', name='DRUG_ID')
# 0
# 0
# Int64Index([1584], dtype='int64', name='DRUG_ID')
# Weid stuff
# ['42623951']
# ['42623951']
# Int64Index([1615], dtype='int64', name='DRUG_ID')
# ['78243717']
# ['78243717']
# Int64Index([1620], dtype='int64', name='DRUG_ID')
# ['57519544']
# ['57519544']
# Int64Index([1622], dtype='int64', name='DRUG_ID')
# ['9936746']
# ['9936746']
# Int64Index([1626], dtype='int64', name='DRUG_ID')
# ['71268957']
# ['71268957']
# Int64Index([1627], dtype='int64', name='DRUG_ID')
# ['71299339']
# ['71299339']
# Int64Index([1634], dtype='int64', name='DRUG_ID')
# 0
# 0
# Int64Index([1716], dtype='int64', name='DRUG_ID')
# Weid stuff
# ['51042438']
# ['51042438']
# Int64Index([2106], dtype='int64', name='DRUG_ID')
# ['91663353']
# ['91663353']
# Int64Index([2154], dtype='int64', name='DRUG_ID')
# ['78357767']
# ['78357767']
# Int64Index([2159], dtype='int64', name='DRUG_ID')
# 0
# 0
# Int64Index([2360], dtype='int64', name='DRUG_ID')
# Weid stuff
# ['124886']
# ['124886']
# Int64Index([2439], dtype='int64', name='DRUG_ID')
# ['126941']
# ['126941']
# Int64Index([1008], dtype='int64', name='DRUG_ID')
# ['23725625']
# ['23725625']
# Int64Index([1017], dtype='int64', name='DRUG_ID')
# ['5328940']
# ['5328940']
# Int64Index([1019], dtype='int64', name='DRUG_ID')
# ['6450551']
# ['6450551']
# Int64Index([1021], dtype='int64', name='DRUG_ID')
# ['984170']
# ['984170']
# Int64Index([1170], dtype='int64', name='DRUG_ID')
# 0
# 0
# Int64Index([1832], dtype='int64', name='DRUG_ID')
# Weid stuff
# ['16654980']
# ['16654980']
# Int64Index([1873], dtype='int64', name='DRUG_ID')
# ['46843057']
# ['46843057']
# Int64Index([1912], dtype='int64', name='DRUG_ID')
# ['71496458']
# ['71496458']
# Int64Index([1919], dtype='int64', name='DRUG_ID')
# ['68289010']
# ['68289010']
# Int64Index([1936], dtype='int64', name='DRUG_ID')
# ['25227847']
# ['25227847']
# Int64Index([2044], dtype='int64', name='DRUG_ID')
# ['11719003']
# ['11719003']
# Int64Index([2047], dtype='int64', name='DRUG_ID')
# 5311497
# 5311497
# Int64Index([2048], dtype='int64', name='DRUG_ID')
# ['9914412']
# ['9914412']
# Int64Index([1050], dtype='int64', name='DRUG_ID')
# ['25262965']
# ['25262965']
# Int64Index([1059], dtype='int64', name='DRUG_ID')
# ['11626560']
# ['11626560']
# Int64Index([1083], dtype='int64', name='DRUG_ID')
# ['5394']
# ['5394']
# Int64Index([1375], dtype='int64', name='DRUG_ID')
# ['58423153']
# ['58423153']
# Int64Index([1449], dtype='int64', name='DRUG_ID')
# ['24737642']
# ['24737642']
# Int64Index([1557], dtype='int64', name='DRUG_ID')
# 5978
# 5978
# Int64Index([1818], dtype='int64', name='DRUG_ID')
# ['234820']
# ['234820']
# Int64Index([1825], dtype='int64', name='DRUG_ID')
# ['73010930']
# ['73010930']
# Int64Index([1580], dtype='int64', name='DRUG_ID')
# ['135398516']
# ['135398516']
# Int64Index([1594], dtype='int64', name='DRUG_ID')
# 0
# 0
# Int64Index([1776], dtype='int64', name='DRUG_ID')
# Weid stuff
# 0
# 0
# Int64Index([1783], dtype='int64', name='DRUG_ID')
# Weid stuff
# ['24821094']
# ['24821094']
# Int64Index([1799], dtype='int64', name='DRUG_ID')
# ['8269']
# ['8269']
# Int64Index([1804], dtype='int64', name='DRUG_ID')
# 0
# 0
# Int64Index([2112], dtype='int64', name='DRUG_ID')
# Weid stuff
# 0
# 0
# Int64Index([2149], dtype='int64', name='DRUG_ID')
# Weid stuff
# ['12035']
# ['12035']
# Int64Index([2499], dtype='int64', name='DRUG_ID')
# ['148124']
# ['148124']
# Int64Index([1007], dtype='int64', name='DRUG_ID')
# ['5311']
# ['5311']
# Int64Index([1012], dtype='int64', name='DRUG_ID')
# 23724530
# 23724530
# Int64Index([1016], dtype='int64', name='DRUG_ID')
# ['2375']
# ['2375']
# Int64Index([1502], dtype='int64', name='DRUG_ID')
# 0
# 0
# Int64Index([1828], dtype='int64', name='DRUG_ID')
# Weid stuff
# ['353472']
# ['353472']
# Int64Index([1830], dtype='int64', name='DRUG_ID')
# 0
# 0
# Int64Index([1839], dtype='int64', name='DRUG_ID')
# Weid stuff
# ['397888']
# ['397888']
# Int64Index([1843], dtype='int64', name='DRUG_ID')
# ['2332']
# ['2332']
# Int64Index([1847], dtype='int64', name='DRUG_ID')
# ['35397514']
# ['35397514']
# Int64Index([1853], dtype='int64', name='DRUG_ID')
# ['9933475']
# ['9933475']
# Int64Index([1922], dtype='int64', name='DRUG_ID')
# ['10385095']
# ['10385095']
# Int64Index([1930], dtype='int64', name='DRUG_ID')
# ['992586']
# ['992586']
# Int64Index([1939], dtype='int64', name='DRUG_ID')
# ['11178236']
# ['11178236']
# Int64Index([1941], dtype='int64', name='DRUG_ID')
# 135691163, 135875424, 2431289
# 135691163, 135875424, 2431289
# Int64Index([1996], dtype='int64', name='DRUG_ID')
# Weid stuff
# 0
# 0
# Int64Index([2010], dtype='int64', name='DRUG_ID')
# Weid stuff
# ['46883536']
# ['46883536']
# Int64Index([1072], dtype='int64', name='DRUG_ID')
# ['3385']
# ['3385']
# Int64Index([1073], dtype='int64', name='DRUG_ID')
# ['24958200']
# ['24958200']
# Int64Index([1177], dtype='int64', name='DRUG_ID')
# 9813758
# 9813758
# Int64Index([1249], dtype='int64', name='DRUG_ID')
# ['135418940']
# ['135418940']
# Int64Index([1268], dtype='int64', name='DRUG_ID')
# ['49831044']
# ['49831044']
# Int64Index([1463], dtype='int64', name='DRUG_ID')
# ['11488320']
# ['11488320']
# Int64Index([1549], dtype='int64', name='DRUG_ID')
# ['51001932']
# ['51001932']
# Int64Index([1561], dtype='int64', name='DRUG_ID')
# 44259
# 44259
# Int64Index([1034], dtype='int64', name='DRUG_ID')
# ['11327430']
# ['11327430']
# Int64Index([1038], dtype='int64', name='DRUG_ID')
# 0
# 0
# Int64Index([1821], dtype='int64', name='DRUG_ID')
# Weid stuff
# 0
# 0
# Int64Index([1733], dtype='int64', name='DRUG_ID')
# Weid stuff
# 0
# 0
# Int64Index([1734], dtype='int64', name='DRUG_ID')
# Weid stuff
# ['10127622']
# ['10127622']
# Int64Index([1736], dtype='int64', name='DRUG_ID')
# 0
# 0
# Int64Index([1784], dtype='int64', name='DRUG_ID')
# Weid stuff
# ['44442376']
# ['44442376']
# Int64Index([2057], dtype='int64', name='DRUG_ID')
# ['76285486']
# ['76285486']
# Int64Index([2157], dtype='int64', name='DRUG_ID')
# ['24785538']
# ['24785538']
# Int64Index([2171], dtype='int64', name='DRUG_ID')
# ['56962337']
# ['56962337']
# Int64Index([2177], dtype='int64', name='DRUG_ID')
# ['24360']
# ['24360']
# Int64Index([1003], dtype='int64', name='DRUG_ID')
# 13342
# 13342
# Int64Index([1004], dtype='int64', name='DRUG_ID')
# ['123631']
# ['123631']
# Int64Index([1010], dtype='int64', name='DRUG_ID')
# 9943465
# 9943465
# Int64Index([1023], dtype='int64', name='DRUG_ID')
# ['176158']
# ['176158']
# Int64Index([1025], dtype='int64', name='DRUG_ID')
# ['11667893']
# ['11667893']
# Int64Index([1029], dtype='int64', name='DRUG_ID')
# ['6914657']
# ['6914657']
# Int64Index([1248], dtype='int64', name='DRUG_ID')
# ['300471']
# ['300471']
# Int64Index([1031], dtype='int64', name='DRUG_ID')
# ['5494449']
# ['5494449']
# Int64Index([1096], dtype='int64', name='DRUG_ID')
# 0
# 0
# Int64Index([1829], dtype='int64', name='DRUG_ID')
# Weid stuff
# ['87371']
# ['87371']
# Int64Index([1831], dtype='int64', name='DRUG_ID')
# 0
# 0
# Int64Index([1833], dtype='int64', name='DRUG_ID')
# Weid stuff
# 0
# 0
# Int64Index([1840], dtype='int64', name='DRUG_ID')
# Weid stuff
# ['11228183']
# ['11228183']
# Int64Index([1910], dtype='int64', name='DRUG_ID')
# ['457193']
# ['457193']
# Int64Index([1911], dtype='int64', name='DRUG_ID')
# ['70676303']
# ['70676303']
# Int64Index([1926], dtype='int64', name='DRUG_ID')
# ['2984337']
# ['2984337']
# Int64Index([1940], dtype='int64', name='DRUG_ID')
# ['68947304']
# ['68947304']
# Int64Index([2045], dtype='int64', name='DRUG_ID')
# ['17755052']
# ['17755052']
# Int64Index([1058], dtype='int64', name='DRUG_ID')
# 9938202
# 9938202
# Int64Index([1069], dtype='int64', name='DRUG_ID')
# ['216239']
# ['216239']
# Int64Index([1085], dtype='int64', name='DRUG_ID')
# ['9887053']
# ['9887053']
# Int64Index([1089], dtype='int64', name='DRUG_ID')
# ['25124816']
# ['25124816']
# Int64Index([1093], dtype='int64', name='DRUG_ID')
# ['11609586']
# ['11609586']
# Int64Index([1133], dtype='int64', name='DRUG_ID')
# ['176870']
# ['176870']
# Int64Index([1168], dtype='int64', name='DRUG_ID')
# ['24856436']
# ['24856436']
# Int64Index([1179], dtype='int64', name='DRUG_ID')
# ['60750']
# ['60750']
# Int64Index([1190], dtype='int64', name='DRUG_ID')
# ['44632017']
# ['44632017']
# Int64Index([1239], dtype='int64', name='DRUG_ID')
# 5460769
# 5460769
# Int64Index([1378], dtype='int64', name='DRUG_ID')
# ['24776445']
# ['24776445']
# Int64Index([1033], dtype='int64', name='DRUG_ID')
# ['11624601']
# ['11624601']
# Int64Index([1043], dtype='int64', name='DRUG_ID')
# ['452548']
# ['452548']
# Int64Index([1809], dtype='int64', name='DRUG_ID')
# ['104741']
# ['104741']
# Int64Index([1816], dtype='int64', name='DRUG_ID')
# 0
# 0
# Int64Index([1820], dtype='int64', name='DRUG_ID')
# Weid stuff
# 0
# 0
# Int64Index([1824], dtype='int64', name='DRUG_ID')
# Weid stuff
# 71522234
# 71522234
# Int64Index([1583], dtype='int64', name='DRUG_ID')
# 0
# 0
# Int64Index([1708], dtype='int64', name='DRUG_ID')
# Weid stuff
# 0
# 0
# Int64Index([1738], dtype='int64', name='DRUG_ID')
# Weid stuff
# 0
# 0
# Int64Index([1739], dtype='int64', name='DRUG_ID')
# Weid stuff
# 0
# 0
# Int64Index([1777], dtype='int64', name='DRUG_ID')
# Weid stuff
# ['46843056']
# ['46843056']
# Int64Index([1778], dtype='int64', name='DRUG_ID')
# 0
# 0
# Int64Index([1780], dtype='int64', name='DRUG_ID')
# Weid stuff
# ['68740']
# ['68740']
# Int64Index([1802], dtype='int64', name='DRUG_ID')
# ['24905401']
# ['24905401']
# Int64Index([2170], dtype='int64', name='DRUG_ID')
# ['864']
# ['864']
# Int64Index([2498], dtype='int64', name='DRUG_ID')
# ['11152667']
# ['11152667']
# Int64Index([1022], dtype='int64', name='DRUG_ID')
# ['44137675']
# ['44137675']
# Int64Index([2169], dtype='int64', name='DRUG_ID')
# ['54685215']
# ['54685215']
# Int64Index([2174], dtype='int64', name='DRUG_ID')
# ['10077147']
# ['10077147']
# Int64Index([1037], dtype='int64', name='DRUG_ID')
# ['9858940']
# ['9858940']
# Int64Index([1194], dtype='int64', name='DRUG_ID')
# 0
# 0
# Int64Index([1836], dtype='int64', name='DRUG_ID')
# Weid stuff
# 0
# 0
# Int64Index([2002], dtype='int64', name='DRUG_ID')
# Weid stuff
# 16681698
# 16681698
# Int64Index([1068], dtype='int64', name='DRUG_ID')
# ['46926350']
# ['46926350']
# Int64Index([1180], dtype='int64', name='DRUG_ID')
# ['104741']
# ['104741']
# Int64Index([1200], dtype='int64', name='DRUG_ID')
# ['25099184']
# ['25099184']
# Int64Index([1250], dtype='int64', name='DRUG_ID')
# ['56649450']
# ['56649450']
# Int64Index([1560], dtype='int64', name='DRUG_ID')
# ['10384072']
# ['10384072']
# Int64Index([1046], dtype='int64', name='DRUG_ID')
# ['3011155']
# ['3011155']
# Int64Index([1814], dtype='int64', name='DRUG_ID')
# 243725
# 243725
# Int64Index([1827], dtype='int64', name='DRUG_ID')
# ['44462758']
# ['44462758']
# Int64Index([1631], dtype='int64', name='DRUG_ID')
# ['44631912']
# ['44631912']
# Int64Index([1632], dtype='int64', name='DRUG_ID')
# 1018
# 1018
# Int64Index([1635], dtype='int64', name='DRUG_ID')
# 0
# 0
# Int64Index([1730], dtype='int64', name='DRUG_ID')
# Weid stuff
# ['8269']
# ['8269']
# Int64Index([1803], dtype='int64', name='DRUG_ID')
# ['117072552']
# ['117072552']
# Int64Index([2110], dtype='int64', name='DRUG_ID')
# ['51000408']
# ['51000408']
# Int64Index([2111], dtype='int64', name='DRUG_ID')
# ['46907787']
# ['46907787']
# Int64Index([2172], dtype='int64', name='DRUG_ID')
# ['70983932']
# ['70983932']
# Int64Index([2359], dtype='int64', name='DRUG_ID')
# 0
# 0
# Int64Index([2361], dtype='int64', name='DRUG_ID')
# Weid stuff
# ['24978538']
# ['24978538']
# Int64Index([1011], dtype='int64', name='DRUG_ID')
# ['44182295']
# ['44182295']
# Int64Index([1014], dtype='int64', name='DRUG_ID')
# ['126565']
# ['126565']
# Int64Index([1024], dtype='int64', name='DRUG_ID')
# ['9956119']
# ['9956119']
# Int64Index([2175], dtype='int64', name='DRUG_ID')
# ['637858']
# ['637858']
# Int64Index([1243], dtype='int64', name='DRUG_ID')
# ['442205']
# ['442205']
# Int64Index([1835], dtype='int64', name='DRUG_ID')
# 5477029
# 5477029
# Int64Index([1838], dtype='int64', name='DRUG_ID')
# 0
# 0
# Int64Index([1844], dtype='int64', name='DRUG_ID')
# Weid stuff
# ['46236925']
# ['46236925']
# Int64Index([1849], dtype='int64', name='DRUG_ID')
# ['25227436']
# ['25227436']
# Int64Index([1916], dtype='int64', name='DRUG_ID')
# ['68107965']
# ['68107965']
# Int64Index([1927], dtype='int64', name='DRUG_ID')
# 0
# 0
# Int64Index([2000], dtype='int64', name='DRUG_ID')
# Weid stuff
# 16224745
# 16224745
# Int64Index([2046], dtype='int64', name='DRUG_ID')
# ['137319711']
# ['137319711']
# Int64Index([1048], dtype='int64', name='DRUG_ID')
# ['24771867']
# ['24771867']
# Int64Index([1051], dtype='int64', name='DRUG_ID')
# ['11977753']
# ['11977753']
# Int64Index([1057], dtype='int64', name='DRUG_ID')
# ['135421339']
# ['135421339']
# Int64Index([1061], dtype='int64', name='DRUG_ID')
# ['10127622']
# ['10127622']
# Int64Index([1062], dtype='int64', name='DRUG_ID')
# ['135440466']
# ['135440466']
# Int64Index([1091], dtype='int64', name='DRUG_ID')
# ['9931954']
# ['9931954']
# Int64Index([1175], dtype='int64', name='DRUG_ID')
# ['387447']
# ['387447']
# Int64Index([1191], dtype='int64', name='DRUG_ID')
# ['56962336']
# ['56962336']
# Int64Index([1237], dtype='int64', name='DRUG_ID')
# ['44462760']
# ['44462760']
# Int64Index([1373], dtype='int64', name='DRUG_ID')
# ['16720766']
# ['16720766']
# Int64Index([1529], dtype='int64', name='DRUG_ID')
# ['24180719']
# ['24180719']
# Int64Index([1036], dtype='int64', name='DRUG_ID')
# 0
# 0
# Int64Index([1586], dtype='int64', name='DRUG_ID')
# Weid stuff
# ['46926973']
# ['46926973']
# Int64Index([1598], dtype='int64', name='DRUG_ID')
# ['59472121']
# ['59472121']
# Int64Index([1613], dtype='int64', name='DRUG_ID')
# ['53469448']
# ['53469448']
# Int64Index([1618], dtype='int64', name='DRUG_ID')
# ['60167849']
# ['60167849']
# Int64Index([1629], dtype='int64', name='DRUG_ID')
# 0
# 0
# Int64Index([1718], dtype='int64', name='DRUG_ID')
# Weid stuff
# 0
# 0
# Int64Index([1732], dtype='int64', name='DRUG_ID')
# Weid stuff
# 0
# 0
# Int64Index([1779], dtype='int64', name='DRUG_ID')
# Weid stuff
# 0
# 0
# Int64Index([1785], dtype='int64', name='DRUG_ID')
# Weid stuff
# ['9887053']
# ['9887053']
# Int64Index([1806], dtype='int64', name='DRUG_ID')
# 0
# 0
# Int64Index([2113], dtype='int64', name='DRUG_ID')
# Weid stuff
# 0
# 0
# Int64Index([2145], dtype='int64', name='DRUG_ID')
# Weid stuff
# ['122540908']
# ['122540908']
# Int64Index([2148], dtype='int64', name='DRUG_ID')
# ['71271629']
# ['71271629']
# Int64Index([2173], dtype='int64', name='DRUG_ID')
# ['644241']
# ['644241']
# Int64Index([1013], dtype='int64', name='DRUG_ID')
# ['10184653']
# ['10184653']
# Int64Index([1032], dtype='int64', name='DRUG_ID')
# ['11455910']
# ['11455910']
# Int64Index([1149], dtype='int64', name='DRUG_ID')
# ['444795']
# ['444795']
# Int64Index([1009], dtype='int64', name='DRUG_ID')
# 10459196
# 10459196
# Int64Index([1039], dtype='int64', name='DRUG_ID')
# ['11655119']
# ['11655119']
# Int64Index([1852], dtype='int64', name='DRUG_ID')
# ['462382']
# ['462382']
# Int64Index([1862], dtype='int64', name='DRUG_ID')
# 0
# 0
# Int64Index([1866], dtype='int64', name='DRUG_ID')
# Weid stuff
# ['52913813']
# ['52913813']
# Int64Index([1918], dtype='int64', name='DRUG_ID')
# ['24788740']
# ['24788740']
# Int64Index([1924], dtype='int64', name='DRUG_ID')
# ['56941241']
# ['56941241']
# Int64Index([1925], dtype='int64', name='DRUG_ID')
# 0
# 0
# Int64Index([1998], dtype='int64', name='DRUG_ID')
# Weid stuff
# ['71268957']
# ['71268957']
# Int64Index([2037], dtype='int64', name='DRUG_ID')
# ['2130404']
# ['2130404']
# Int64Index([2039], dtype='int64', name='DRUG_ID')
# 9927531
# 9927531
# Int64Index([2043], dtype='int64', name='DRUG_ID')
# 11433190
# 11433190
# Int64Index([1047], dtype='int64', name='DRUG_ID')
# ['2314623']
# ['2314623']
# Int64Index([1067], dtype='int64', name='DRUG_ID')
# ['2733526']
# ['2733526']
# Int64Index([1199], dtype='int64', name='DRUG_ID')
# ['2907']
# ['2907']
# Int64Index([1512], dtype='int64', name='DRUG_ID')
# ['208908']
# ['208908']
# Int64Index([1558], dtype='int64', name='DRUG_ID')
# ['60700']
# ['60700']
# Int64Index([1808], dtype='int64', name='DRUG_ID')
# ['4212']
# ['4212']
# Int64Index([1810], dtype='int64', name='DRUG_ID')
# ['457193']
# ['457193']
# Int64Index([1811], dtype='int64', name='DRUG_ID')
# 135398738
# 135398738
# Int64Index([1815], dtype='int64', name='DRUG_ID')
# ['72201027']
# ['72201027']
# Int64Index([1582], dtype='int64', name='DRUG_ID')
# 0
# 0
# Int64Index([1585], dtype='int64', name='DRUG_ID')
# Weid stuff
# ['49847690']
# ['49847690']
# Int64Index([1617], dtype='int64', name='DRUG_ID')
# ['46943432']
# ['46943432']
# Int64Index([1624], dtype='int64', name='DRUG_ID')
# ['118693659']
# ['118693659']
# Int64Index([1706], dtype='int64', name='DRUG_ID')
# 0
# 0
# Int64Index([1712], dtype='int64', name='DRUG_ID')
# Weid stuff
# 0
# 0
# Int64Index([1713], dtype='int64', name='DRUG_ID')
# Weid stuff
# ['131634760']
# ['131634760']
# Int64Index([1720], dtype='int64', name='DRUG_ID')
# ['446541']
# ['446541']
# Int64Index([2055], dtype='int64', name='DRUG_ID')
# ['135905416']
# ['135905416']
# Int64Index([2109], dtype='int64', name='DRUG_ID')
# ['121271792']
# ['121271792']
# Int64Index([2158], dtype='int64', name='DRUG_ID')
# 0
# 0
# Int64Index([2438], dtype='int64', name='DRUG_ID')
# Weid stuff
# ['5702198']
# ['5702198']
# Int64Index([1005], dtype='int64', name='DRUG_ID')
# ['6253']
# ['6253']
# Int64Index([1006], dtype='int64', name='DRUG_ID')
# ['11960529']
# ['11960529']
# Int64Index([1018], dtype='int64', name='DRUG_ID')
# ['216326']
# ['216326']
# Int64Index([1020], dtype='int64', name='DRUG_ID')
# ['6505803']
# ['6505803']
# Int64Index([1026], dtype='int64', name='DRUG_ID')
# ['643462']
# ['643462']
# Int64Index([1845], dtype='int64', name='DRUG_ID')
# 73555129
# 73555129
# Int64Index([1855], dtype='int64', name='DRUG_ID')
# ['11719003']
# ['11719003']
# Int64Index([1908], dtype='int64', name='DRUG_ID')
# 54761306, 86660217, 76189844, 54761305, 129317940
# 54761306, 86660217, 76189844, 54761305, 129317940
# Int64Index([1917], dtype='int64', name='DRUG_ID')
# Weid stuff
# ['91668541']
# ['91668541']
# Int64Index([1928], dtype='int64', name='DRUG_ID')
# ['227681']
# ['227681']
# Int64Index([1931], dtype='int64', name='DRUG_ID')
# 0
# 0
# Int64Index([1999], dtype='int64', name='DRUG_ID')
# Weid stuff
# 0
# 0
# Int64Index([2003], dtype='int64', name='DRUG_ID')
# Weid stuff
# ['1401']
# ['1401']
# Int64Index([1049], dtype='int64', name='DRUG_ID')
# ['135400873']
# ['135400873']
# Int64Index([1052], dtype='int64', name='DRUG_ID')
# ['24964624']
# ['24964624']
# Int64Index([1053], dtype='int64', name='DRUG_ID')
# ['5330286']
# ['5330286']
# Int64Index([1054], dtype='int64', name='DRUG_ID')
# ['9826528']
# ['9826528']
# Int64Index([1060], dtype='int64', name='DRUG_ID')
# ['3062316']
# ['3062316']
# Int64Index([1079], dtype='int64', name='DRUG_ID')
# ['36314']
# ['36314']
# Int64Index([1080], dtype='int64', name='DRUG_ID')
# ['11364421']
# ['11364421']
# Int64Index([1086], dtype='int64', name='DRUG_ID')
# ['60838']
# ['60838']
# Int64Index([1088], dtype='int64', name='DRUG_ID')
# ['16747683']
# ['16747683']
# Int64Index([1401], dtype='int64', name='DRUG_ID')
# 0
# 0
# Int64Index([1428], dtype='int64', name='DRUG_ID')
# Weid stuff
# ['25262792']
# ['25262792']
# Int64Index([1441], dtype='int64', name='DRUG_ID')
# ['104842']
# ['104842']
# Int64Index([1494], dtype='int64', name='DRUG_ID')
# ['25126798']
# ['25126798']
# Int64Index([1507], dtype='int64', name='DRUG_ID')
# ['11640390']
# ['11640390']
# Int64Index([1510], dtype='int64', name='DRUG_ID')
# ['41867']
# ['41867']
# Int64Index([1511], dtype='int64', name='DRUG_ID')
# ['51042438']
# ['51042438']
# Int64Index([1553], dtype='int64', name='DRUG_ID')
# ['156422']
# ['156422']
# Int64Index([1042], dtype='int64', name='DRUG_ID')
# ['657237']
# ['657237']
# Int64Index([1813], dtype='int64', name='DRUG_ID')
# ['148124']
# ['148124']
# Int64Index([1819], dtype='int64', name='DRUG_ID')
# 0
# 0
# Int64Index([1826], dtype='int64', name='DRUG_ID')
# Weid stuff
# ['57345410']
# ['57345410']
# Int64Index([1563], dtype='int64', name='DRUG_ID')
# ['24866313']
# ['24866313']
# Int64Index([1564], dtype='int64', name='DRUG_ID')
# ['2155128']
# ['2155128']
# Int64Index([1576], dtype='int64', name='DRUG_ID')
# ['3899']
# ['3899']
# Int64Index([1578], dtype='int64', name='DRUG_ID')
# ['72943187']
# ['72943187']
# Int64Index([1581], dtype='int64', name='DRUG_ID')
# ['4261']
# ['4261']
# Int64Index([1593], dtype='int64', name='DRUG_ID')
# ['72200024']
# ['72200024']
# Int64Index([1614], dtype='int64', name='DRUG_ID')
# ['24753719']
# ['24753719']
# Int64Index([1621], dtype='int64', name='DRUG_ID')
# ['135564749']
# ['135564749']
# Int64Index([1625], dtype='int64', name='DRUG_ID')
# ['59473233']
# ['59473233']
# Int64Index([1630], dtype='int64', name='DRUG_ID')
# 0
# 0
# Int64Index([1709], dtype='int64', name='DRUG_ID')
# Weid stuff
# 0
# 0
# Int64Index([1714], dtype='int64', name='DRUG_ID')
# Weid stuff
# 0
# 0
# Int64Index([1782], dtype='int64', name='DRUG_ID')
# Weid stuff
# ['51039095']
# ['51039095']
# Int64Index([1786], dtype='int64', name='DRUG_ID')
# ['2578']
# ['2578']
# Int64Index([1807], dtype='int64', name='DRUG_ID')
# ['11634725']
# ['11634725']
# Int64Index([2096], dtype='int64', name='DRUG_ID')
# ['118704762']
# ['118704762']
# Int64Index([2107], dtype='int64', name='DRUG_ID')
# ['9444']
# ['9444']
# Int64Index([2156], dtype='int64', name='DRUG_ID')
# 0
# 0
# Int64Index([2362], dtype='int64', name='DRUG_ID')
# Weid stuff
# ['5278396']
# ['5278396']
# Int64Index([1030], dtype='int64', name='DRUG_ID')
# ['51371303']
# ['51371303']
# Int64Index([1129], dtype='int64', name='DRUG_ID')
# ['16095342']
# ['16095342']
# Int64Index([1192], dtype='int64', name='DRUG_ID')
# CPU times: user 8.19 s, sys: 1.04 s, total: 9.23 s
# Wall time: 6min 2s

# %%
drug_features.head(15)
# Out:
#            Drug_Name  ...                    inchi_key
# DRUG_ID               ...
# 1834          743380  ...                          NaN
# 1854           MN-64  ...  PYTOHIUBXSJKQH-UHFFFAOYSA-N
# 1909      Venetoclax  ...  LQBVNQSMGBZMKD-UHFFFAOYSA-N
# 1913        AGI-5198  ...  FNYGWXSATBUBER-UHFFFAOYSA-N
# 1915         AZD3759  ...  MXDSJQHFFDGFDK-CYBMUJFWSA-N
# 1932      NVP-ADW742  ...  LSFLAQVDISHMNB-UHFFFAOYSA-N
# 1933          P22077  ...  RMAMGGNACJHXHO-UHFFFAOYSA-N
# 1997        WEHI-539  ...  JKMWZKPAXZBYEH-JWHWKPFMSA-N
# 2011     ICL-SIRT078  ...                          NaN
# 2038         UNC0638  ...  QOECJCJVIMVJGX-UHFFFAOYSA-N
# 2040       Foretinib  ...  CXQHYVUVSFXTMY-UHFFFAOYSA-N
# 1084       Rapamycin  ...  QFJCIRLUMZQUOT-HPLJOQBZSA-N
# 1131      PRIMA-1MET  ...  BGBNULCRKBVAKL-UHFFFAOYSA-N
# 1259     Talazoparib  ...  HWGQMRYQVZSGDQ-HZPDHXFCSA-N
# 1372      Trametinib  ...  LIRYPHYGHXZJBZ-UHFFFAOYSA-N
#
# [15 rows x 27 columns]

# %%
len(manual_corrections)
# Out:
# 25

# %%
drugs_with_pubchem_id = drug_features[drug_features["PubChem_ID"]!=0].index
print("All drugs: %d, With known PubChem_Id: %d" % (drug_features.shape[0], len(drugs_with_pubchem_id)))
# Out:
# All drugs: 297, With known PubChem_Id: 243

# %%
drug_features.to_csv('drug_features_GDSC2.csv', index=False)

# %% [markdown]
# ## Preprocessing Text PubChem characteristics

# %% [markdown]
# ### Presence of some elements (11 elements)

# %%
# %%time
all_elements = list(set(drug_features["elements"].str.split(",", expand=True).fillna(0).values.flatten())- set([0," 'C'", "'C'", " 'H'"]))
all_elements

elements_in_drugs= list(set([atom.strip(" ").strip("'") for atom in all_elements]))
exceptions =[]
for drug_index in drug_features.index:
    compound_elements = drug_features.loc[drug_index, "elements"]
    print(compound_elements)
    try:
        for i, atom in list(enumerate(elements_in_drugs)):
            if atom in compound_elements:
                drug_features.loc[drug_index, atom] = 1
                print(atom, "Yes")
            else:
                drug_features.loc[drug_index, atom] = 0
                print(atom, "No")
    except:
        exceptions.append(drug_index)
        drug_features.loc[drug_index, atom] = 0

print("Exceptions:", drug_features.loc[exceptions, :].shape[0])
print("Elements in drugs:", len(elements_in_drugs), elements_in_drugs)
# Out:
# nan
# 'H', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N No
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'C', 'S', 'N', 'O', 'H', 'Cl'
# P No
# Br No
# B No
# Pt No
# S Yes
# N Yes
# Cl Yes
# O Yes
# F No
# H Yes
# I No
# 'C', 'N', 'O', 'F', 'H'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F Yes
# H Yes
# I No
# 'C', 'N', 'O', 'F', 'H', 'Cl'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl Yes
# O Yes
# F Yes
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'C', 'S', 'N', 'O', 'F', 'H'
# P No
# Br No
# B No
# Pt No
# S Yes
# N Yes
# Cl No
# O Yes
# F Yes
# H Yes
# I No
# 'C', 'S', 'N', 'O', 'H'
# P No
# Br No
# B No
# Pt No
# S Yes
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# nan
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'C', 'N', 'O', 'F', 'H'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F Yes
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'C', 'N', 'O', 'F', 'H'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F Yes
# H Yes
# I No
# 'C', 'N', 'O', 'F', 'H', 'I'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F Yes
# H Yes
# I Yes
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'C', 'S', 'N', 'O', 'H'
# P No
# Br No
# B No
# Pt No
# S Yes
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'C', 'S', 'N', 'O', 'H'
# P No
# Br No
# B No
# Pt No
# S Yes
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# nan
# 'C', 'S', 'N', 'O', 'F', 'H'
# P No
# Br No
# B No
# Pt No
# S Yes
# N Yes
# Cl No
# O Yes
# F Yes
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'C', 'S', 'N', 'O', 'H', 'Cl'
# P No
# Br No
# B No
# Pt No
# S Yes
# N Yes
# Cl Yes
# O Yes
# F No
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'C', 'S', 'N', 'O', 'F', 'H'
# P No
# Br No
# B No
# Pt No
# S Yes
# N Yes
# Cl No
# O Yes
# F Yes
# H Yes
# I No
# nan
# 'C', 'N', 'O', 'F', 'H', 'Cl'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl Yes
# O Yes
# F Yes
# H Yes
# I No
# 'N', 'C', 'H', 'Cl'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl Yes
# O No
# F No
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# nan
# 'C', 'S', 'N', 'O', 'H'
# P No
# Br No
# B No
# Pt No
# S Yes
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'C', 'N', 'O', 'F', 'H'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F Yes
# H Yes
# I No
# 'C', 'N', 'Cl', 'O', 'H'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl Yes
# O Yes
# F No
# H Yes
# I No
# 'C', 'S', 'N', 'O', 'H'
# P No
# Br No
# B No
# Pt No
# S Yes
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# nan
# 'C', 'N', 'O', 'F', 'H'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F Yes
# H Yes
# I No
# 'C', 'S', 'N', 'O', 'F', 'H', 'Cl'
# P No
# Br No
# B No
# Pt No
# S Yes
# N Yes
# Cl Yes
# O Yes
# F Yes
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'N', 'H', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O No
# F No
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'C', 'N', 'Cl', 'O', 'H'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl Yes
# O Yes
# F No
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'C', 'N', 'O', 'F', 'H', 'Cl'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl Yes
# O Yes
# F Yes
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'C', 'S', 'N', 'O', 'H'
# P No
# Br No
# B No
# Pt No
# S Yes
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'C', 'S', 'N', 'O', 'F', 'H'
# P No
# Br No
# B No
# Pt No
# S Yes
# N Yes
# Cl No
# O Yes
# F Yes
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'H', 'Br', 'O', 'C'
# P No
# Br Yes
# B Yes
# Pt No
# S No
# N No
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'C', 'S', 'N', 'O', 'H'
# P No
# Br No
# B No
# Pt No
# S Yes
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# nan
# nan
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# nan
# nan
# 'C', 'S', 'N', 'O', 'H'
# P No
# Br No
# B No
# Pt No
# S Yes
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'C', 'S', 'N', 'O', 'F', 'H'
# P No
# Br No
# B No
# Pt No
# S Yes
# N Yes
# Cl No
# O Yes
# F Yes
# H Yes
# I No
# nan
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# nan
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'N', 'H', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O No
# F No
# H Yes
# I No
# 'Br', 'C', 'S', 'N', 'O', 'H'
# P No
# Br Yes
# B Yes
# Pt No
# S Yes
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'C', 'N', 'O', 'F', 'H'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F Yes
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'Br', 'C', 'S', 'N', 'O', 'H'
# P No
# Br Yes
# B Yes
# Pt No
# S Yes
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'Br', 'C', 'N', 'O', 'H'
# P No
# Br Yes
# B Yes
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# nan
# nan
# 'C', 'S', 'N', 'O', 'F', 'H', 'Cl'
# P No
# Br No
# B No
# Pt No
# S Yes
# N Yes
# Cl Yes
# O Yes
# F Yes
# H Yes
# I No
# 'C', 'N', 'O', 'F', 'H'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F Yes
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'N', 'H', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O No
# F No
# H Yes
# I No
# 'C', 'S', 'N', 'O', 'F', 'H'
# P No
# Br No
# B No
# Pt No
# S Yes
# N Yes
# Cl No
# O Yes
# F Yes
# H Yes
# I No
# 'C', 'N', 'O', 'F', 'H', 'Cl'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl Yes
# O Yes
# F Yes
# H Yes
# I No
# 'C', 'N', 'O', 'F', 'H', 'Cl'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl Yes
# O Yes
# F Yes
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'C', 'S', 'N', 'O', 'H'
# P No
# Br No
# B No
# Pt No
# S Yes
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# nan
# nan
# nan
# 'Br', 'C', 'N', 'O', 'F', 'H', 'Cl'
# P No
# Br Yes
# B Yes
# Pt No
# S No
# N Yes
# Cl Yes
# O Yes
# F Yes
# H Yes
# I No
# nan
# 'N', 'H', 'C', 'S'
# P No
# Br No
# B No
# Pt No
# S Yes
# N Yes
# Cl No
# O No
# F No
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'C', 'N', 'O', 'F', 'H'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F Yes
# H Yes
# I No
# 'Br', 'C', 'N', 'O', 'H'
# P No
# Br Yes
# B Yes
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'C', 'N', 'O', 'F', 'H', 'Cl'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl Yes
# O Yes
# F Yes
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'C', 'N', 'Cl', 'O', 'H'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl Yes
# O Yes
# F No
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'C', 'S', 'N', 'O', 'H'
# P No
# Br No
# B No
# Pt No
# S Yes
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'C', 'S', 'N', 'O', 'H'
# P No
# Br No
# B No
# Pt No
# S Yes
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# nan
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# nan
# nan
# 'C', 'S', 'N', 'O', 'H', 'Cl'
# P No
# Br No
# B No
# Pt No
# S Yes
# N Yes
# Cl Yes
# O Yes
# F No
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'C', 'S', 'N', 'O', 'H'
# P No
# Br No
# B No
# Pt No
# S Yes
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'C', 'S', 'N', 'O', 'H'
# P No
# Br No
# B No
# Pt No
# S Yes
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'N', 'F', 'H', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O No
# F Yes
# H Yes
# I No
# 'C', 'S', 'N', 'O', 'H'
# P No
# Br No
# B No
# Pt No
# S Yes
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'C', 'S', 'N', 'O', 'F', 'H', 'Cl'
# P No
# Br No
# B No
# Pt No
# S Yes
# N Yes
# Cl Yes
# O Yes
# F Yes
# H Yes
# I No
# 'C', 'N', 'O', 'F', 'H', 'Cl'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl Yes
# O Yes
# F Yes
# H Yes
# I No
# 'Pt', 'C', 'N', 'O', 'H'
# P Yes
# Br No
# B No
# Pt Yes
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'C', 'S', 'N', 'O', 'F', 'H'
# P No
# Br No
# B No
# Pt No
# S Yes
# N Yes
# Cl No
# O Yes
# F Yes
# H Yes
# I No
# 'N', 'H', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O No
# F No
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'C', 'N', 'O', 'F', 'H'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F Yes
# H Yes
# I No
# 'C', 'N', 'Cl', 'O', 'H'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl Yes
# O Yes
# F No
# H Yes
# I No
# 'C', 'S', 'N', 'O', 'H'
# P No
# Br No
# B No
# Pt No
# S Yes
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'C', 'S', 'N', 'O', 'H', 'Cl'
# P No
# Br No
# B No
# Pt No
# S Yes
# N Yes
# Cl Yes
# O Yes
# F No
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'H', 'O', 'C', 'S'
# P No
# Br No
# B No
# Pt No
# S Yes
# N No
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'C', 'S', 'O', 'F', 'H'
# P No
# Br No
# B No
# Pt No
# S Yes
# N No
# Cl No
# O Yes
# F Yes
# H Yes
# I No
# nan
# nan
# 'N', 'H', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O No
# F No
# H Yes
# I No
# nan
# nan
# nan
# nan
# 'C', 'S', 'N', 'O', 'F', 'H', 'Cl'
# P No
# Br No
# B No
# Pt No
# S Yes
# N Yes
# Cl Yes
# O Yes
# F Yes
# H Yes
# I No
# nan
# 'P', 'C', 'N', 'O', 'H'
# P Yes
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'C', 'N', 'Cl', 'O', 'H'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl Yes
# O Yes
# F No
# H Yes
# I No
# 'H', 'O', 'C', 'S'
# P No
# Br No
# B No
# Pt No
# S Yes
# N No
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'C', 'S', 'N', 'O', 'F', 'H'
# P No
# Br No
# B No
# Pt No
# S Yes
# N Yes
# Cl No
# O Yes
# F Yes
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'C', 'S', 'N', 'O', 'H', 'I'
# P No
# Br No
# B No
# Pt No
# S Yes
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I Yes
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# nan
# nan
# 'C', 'S', 'N', 'O', 'H'
# P No
# Br No
# B No
# Pt No
# S Yes
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'C', 'S', 'O', 'F', 'H'
# P No
# Br No
# B No
# Pt No
# S Yes
# N No
# Cl No
# O Yes
# F Yes
# H Yes
# I No
# 'N', 'F', 'H', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O No
# F Yes
# H Yes
# I No
# 'C', 'S', 'N', 'O', 'F', 'H'
# P No
# Br No
# B No
# Pt No
# S Yes
# N Yes
# Cl No
# O Yes
# F Yes
# H Yes
# I No
# 'C', 'N', 'Cl', 'O', 'H'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl Yes
# O Yes
# F No
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'H', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N No
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# nan
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'C', 'S', 'N', 'O', 'H'
# P No
# Br No
# B No
# Pt No
# S Yes
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'C', 'S', 'N', 'O', 'H', 'Cl'
# P No
# Br No
# B No
# Pt No
# S Yes
# N Yes
# Cl Yes
# O Yes
# F No
# H Yes
# I No
# 'C', 'S', 'N', 'O', 'H', 'Cl'
# P No
# Br No
# B No
# Pt No
# S Yes
# N Yes
# Cl Yes
# O Yes
# F No
# H Yes
# I No
# nan
# 'C', 'S', 'N', 'O', 'F', 'H', 'Cl'
# P No
# Br No
# B No
# Pt No
# S Yes
# N Yes
# Cl Yes
# O Yes
# F Yes
# H Yes
# I No
# 'C', 'S', 'N', 'O', 'F', 'H', 'I'
# P No
# Br No
# B No
# Pt No
# S Yes
# N Yes
# Cl No
# O Yes
# F Yes
# H Yes
# I Yes
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'N', 'C', 'H', 'Cl'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl Yes
# O No
# F No
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'H', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N No
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'H', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N No
# Cl No
# O Yes
# F No
# H Yes
# I No
# nan
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'C', 'N', 'Cl', 'O', 'H'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl Yes
# O Yes
# F No
# H Yes
# I No
# 'C', 'N', 'O', 'F', 'H'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F Yes
# H Yes
# I No
# nan
# 'Br', 'N', 'H', 'C'
# P No
# Br Yes
# B Yes
# Pt No
# S No
# N Yes
# Cl No
# O No
# F No
# H Yes
# I No
# 'C', 'S', 'N', 'O', 'H'
# P No
# Br No
# B No
# Pt No
# S Yes
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'C', 'N', 'O', 'F', 'H', 'Cl'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl Yes
# O Yes
# F Yes
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'Br', 'C', 'N', 'O', 'F', 'H', 'Cl'
# P No
# Br Yes
# B Yes
# Pt No
# S No
# N Yes
# Cl Yes
# O Yes
# F Yes
# H Yes
# I No
# 'C', 'N', 'Cl', 'O', 'H'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl Yes
# O Yes
# F No
# H Yes
# I No
# 'C', 'N', 'O', 'F', 'H'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F Yes
# H Yes
# I No
# 'B', 'C', 'N', 'O', 'H'
# P No
# Br No
# B Yes
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'C', 'S', 'N', 'O', 'F', 'H'
# P No
# Br No
# B No
# Pt No
# S Yes
# N Yes
# Cl No
# O Yes
# F Yes
# H Yes
# I No
# 'C', 'S', 'N', 'O', 'H'
# P No
# Br No
# B No
# Pt No
# S Yes
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'C', 'S', 'N', 'O', 'F', 'H', 'Cl'
# P No
# Br No
# B No
# Pt No
# S Yes
# N Yes
# Cl Yes
# O Yes
# F Yes
# H Yes
# I No
# nan
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'C', 'S', 'N', 'O', 'H'
# P No
# Br No
# B No
# Pt No
# S Yes
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'C', 'N', 'O', 'F', 'H'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F Yes
# H Yes
# I No
# 'N', 'H', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O No
# F No
# H Yes
# I No
# nan
# nan
# nan
# nan
# 'Pt', 'C', 'N', 'O', 'H'
# P Yes
# Br No
# B No
# Pt Yes
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# nan
# nan
# 'P', 'C', 'N', 'O', 'H'
# P Yes
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'C', 'S', 'N', 'O', 'H'
# P No
# Br No
# B No
# Pt No
# S Yes
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'C', 'N', 'O', 'F', 'H'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F Yes
# H Yes
# I No
# 'C', 'N', 'O', 'F', 'H', 'Cl'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl Yes
# O Yes
# F Yes
# H Yes
# I No
# 'C', 'S', 'N', 'O', 'H'
# P No
# Br No
# B No
# Pt No
# S Yes
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'H', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N No
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'H', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N No
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# nan
# 'C', 'N', 'O', 'F', 'H'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F Yes
# H Yes
# I No
# 'C', 'N', 'Cl', 'O', 'H'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl Yes
# O Yes
# F No
# H Yes
# I No
# 'C', 'N', 'O', 'F', 'H', 'Cl'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl Yes
# O Yes
# F Yes
# H Yes
# I No
# nan
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'C', 'N', 'Cl', 'O', 'H'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl Yes
# O Yes
# F No
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'C', 'N', 'Cl', 'O', 'H'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl Yes
# O Yes
# F No
# H Yes
# I No
# 'H', 'O', 'C', 'S'
# P No
# Br No
# B No
# Pt No
# S Yes
# N No
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'P', 'C', 'N', 'O', 'H', 'Cl'
# P Yes
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl Yes
# O Yes
# F No
# H Yes
# I No
# 'C', 'S', 'N', 'O', 'F', 'H', 'Cl'
# P No
# Br No
# B No
# Pt No
# S Yes
# N Yes
# Cl Yes
# O Yes
# F Yes
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'C', 'N', 'Cl', 'O', 'H'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl Yes
# O Yes
# F No
# H Yes
# I No
# nan
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'C', 'N', 'Cl', 'O', 'H'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl Yes
# O Yes
# F No
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# nan
# nan
# 'C', 'S', 'N', 'O', 'H', 'Cl'
# P No
# Br No
# B No
# Pt No
# S Yes
# N Yes
# Cl Yes
# O Yes
# F No
# H Yes
# I No
# 'H', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N No
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# nan
# 'N', 'Pt', 'H', 'Cl'
# P Yes
# Br No
# B No
# Pt Yes
# S No
# N Yes
# Cl Yes
# O No
# F No
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'H', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N No
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'C', 'N', 'O', 'I', 'H', 'Cl'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl Yes
# O Yes
# F No
# H Yes
# I Yes
# 'C', 'N', 'Cl', 'O', 'H'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl Yes
# O Yes
# F No
# H Yes
# I No
# nan
# 'C', 'S', 'N', 'O', 'F', 'H'
# P No
# Br No
# B No
# Pt No
# S Yes
# N Yes
# Cl No
# O Yes
# F Yes
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# nan
# nan
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'C', 'S', 'N', 'O', 'H'
# P No
# Br No
# B No
# Pt No
# S Yes
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'C', 'N', 'O', 'F', 'H', 'I'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F Yes
# H Yes
# I Yes
# 'C', 'S', 'N', 'O', 'H', 'Cl'
# P No
# Br No
# B No
# Pt No
# S Yes
# N Yes
# Cl Yes
# O Yes
# F No
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'C', 'S', 'N', 'O', 'H'
# P No
# Br No
# B No
# Pt No
# S Yes
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# nan
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'N', 'H', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O No
# F No
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'C', 'N', 'O', 'F', 'H', 'Cl'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl Yes
# O Yes
# F Yes
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'C', 'N', 'O', 'F', 'H'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F Yes
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# nan
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'C', 'S', 'N', 'O', 'H'
# P No
# Br No
# B No
# Pt No
# S Yes
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'C', 'N', 'O', 'F', 'H'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F Yes
# H Yes
# I No
# 'C', 'S', 'N', 'O', 'H'
# P No
# Br No
# B No
# Pt No
# S Yes
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'C', 'N', 'Cl', 'O', 'H'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl Yes
# O Yes
# F No
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# nan
# nan
# nan
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'C', 'N', 'Cl', 'O', 'H'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl Yes
# O Yes
# F No
# H Yes
# I No
# 'C', 'N', 'O', 'F', 'H', 'Cl'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl Yes
# O Yes
# F Yes
# H Yes
# I No
# 'C', 'N', 'O', 'F', 'H'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F Yes
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# nan
# 'C', 'S', 'N', 'O', 'H'
# P No
# Br No
# B No
# Pt No
# S Yes
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# 'N', 'F', 'H', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O No
# F Yes
# H Yes
# I No
# 'H', 'N', 'O', 'C'
# P No
# Br No
# B No
# Pt No
# S No
# N Yes
# Cl No
# O Yes
# F No
# H Yes
# I No
# Exceptions: 56
# Elements in drugs: 11 ['P', 'Br', 'B', 'Pt', 'S', 'N', 'Cl', 'O', 'F', 'H', 'I']
# CPU times: user 302 ms, sys: 53.7 ms, total: 356 ms
# Wall time: 590 ms

# %%
drug_features["Br"].value_counts()
# Out:
# 0.0    233
# 1.0      8
# Name: Br, dtype: int64

# %%
drug_features
# Out:
#              Drug_Name                  Target  ...    H    I
# DRUG_ID                                         ...
# 1834            743380                       -  ...  NaN  NaN
# 1854             MN-64            TNKS1, TNKS2  ...  1.0  0.0
# 1909        Venetoclax                    BCL2  ...  1.0  0.0
# 1913          AGI-5198            IDH1 (R132H)  ...  1.0  0.0
# 1915           AZD3759                    EGFR  ...  1.0  0.0
# ...                ...                     ...  ...  ...  ...
# 2156     5-azacytidine  DNA methyltransferases  ...  1.0  0.0
# 2362           THR-103              Mutant RAS  ...  NaN  NaN
# 1030          KU-55933                     ATM  ...  1.0  0.0
# 1129        PF-4708671                    S6K1  ...  1.0  0.0
# 1192        GSK269962A            ROCK1, ROCK2  ...  1.0  0.0
#
# [297 rows x 38 columns]

# %%
drug_features.to_csv("GDSC2_drug_features_with_pubchem_properties.csv")

# %% [markdown]
# ### Write PubChem names

# %%
PubChem_features = ["molecular_weight","2bonds", "3bonds", "xlogp", "formal_charge", 
    "surface_area", "complexity", "h_bond_donor_count", 
    "h_bond_acceptor_count", "rotatable_bond_count",
    "heavy_atom_count", "atom_stereo_count", "defined_atom_stereo_count",
    "undefined_atom_stereo_count", "bond_stereo_count", "covalent_unit_count",
    'B', 'I', 'Br', 'Cl', 'O', 'N', 'F', 'P', 'S', 'Pt']

with open("X_PubChem_properties.txt", 'w') as f:
    for s in PubChem_features:
        f.write(str(s) + '\n')

print("Number of PubChem features:", len(PubChem_features))
# Out:
# Number of PubChem features: 26

# %% [markdown]
# ## Part 2: Preprocessing Drugs description from original data

# %% [markdown]
# In this section, we are going to have some dumnies columns for Target and Target_Pathway
#
# Converting of Target Pathway resulted in 26 new columns
#
# It is also worth considering elements columns and that deleting columns with C and H which are present in all the compounds

# %% [markdown]
# ### Dumnies for Target (229) and Target_Pathway (23)

# %%
drug_features.head(3)
# Out:
#           Drug_Name        Target        Target_Pathway  ...    F    H    I
# DRUG_ID                                                  ...
# 1834         743380             -          Unclassified  ...  NaN  NaN  NaN
# 1854          MN-64  TNKS1, TNKS2         WNT signaling  ...  0.0  1.0  0.0
# 1909     Venetoclax          BCL2  Apoptosis regulation  ...  0.0  1.0  0.0
#
# [3 rows x 38 columns]

# %%
drug_features.dtypes
# Out:
# Drug_Name                       object
# Target                          object
# Target_Pathway                  object
# PubChem                         object
# deriv_found                    float64
# PubChem_ID                      object
# molecular_weight                object
# elements                        object
# 2bonds                         float64
# 3bonds                         float64
# xlogp                          float64
# formal_charge                  float64
# surface_area                   float64
# complexity                     float64
# h_bond_donor_count             float64
# h_bond_acceptor_count          float64
# rotatable_bond_count           float64
# heavy_atom_count               float64
# atom_stereo_count              float64
# defined_atom_stereo_count      float64
# undefined_atom_stereo_count    float64
# bond_stereo_count              float64
# covalent_unit_count            float64
# molecular_formula               object
# canonical_smiles                object
# inchi_string                    object
# inchi_key                       object
# P                              float64
# Br                             float64
# B                              float64
# Pt                             float64
# S                              float64
# N                              float64
# Cl                             float64
# O                              float64
# F                              float64
# H                              float64
# I                              float64
# dtype: object

# %%
targets = ""
for x in drug_features.Target.values:
    targets = targets + ", " + str(x)
targets = list(set(targets.split(", ")[1:]))
print("Number of targets:", len(targets))
# Out:
# Number of targets: 242

# %%
df_target = pd.DataFrame(data = np.int32(np.zeros([drug_features.shape[0], len(targets)])), 
                         index = drug_features.index, 
                         columns = targets)

# %%
df_target
# Out:
#          MTORC2  NAMPT  AR  KDM1  ...  NTRK2  BRD4  ACVR1C  TBK1
# DRUG_ID                           ...
# 1834          0      0   0     0  ...      0     0       0     0
# 1854          0      0   0     0  ...      0     0       0     0
# 1909          0      0   0     0  ...      0     0       0     0
# 1913          0      0   0     0  ...      0     0       0     0
# 1915          0      0   0     0  ...      0     0       0     0
# ...         ...    ...  ..   ...  ...    ...   ...     ...   ...
# 2156          0      0   0     0  ...      0     0       0     0
# 2362          0      0   0     0  ...      0     0       0     0
# 1030          0      0   0     0  ...      0     0       0     0
# 1129          0      0   0     0  ...      0     0       0     0
# 1192          0      0   0     0  ...      0     0       0     0
#
# [297 rows x 242 columns]

# %%
for index in drug_features.index:
    targets_i = str(drug_features.loc[index, 'Target']).split(', ')
    df_target.loc[index, targets_i]=1
df_target.shape
# Out:
# (297, 242)

# %%
df_target
# Out:
#          MTORC2  NAMPT  AR  KDM1  ...  NTRK2  BRD4  ACVR1C  TBK1
# DRUG_ID                           ...
# 1834          0      0   0     0  ...      0     0       0     0
# 1854          0      0   0     0  ...      0     0       0     0
# 1909          0      0   0     0  ...      0     0       0     0
# 1913          0      0   0     0  ...      0     0       0     0
# 1915          0      0   0     0  ...      0     0       0     0
# ...         ...    ...  ..   ...  ...    ...   ...     ...   ...
# 2156          0      0   0     0  ...      0     0       0     0
# 2362          0      0   0     0  ...      0     0       0     0
# 1030          0      0   0     0  ...      0     0       0     0
# 1129          0      0   0     0  ...      0     0       0     0
# 1192          0      0   0     0  ...      0     0       0     0
#
# [297 rows x 242 columns]

# %%
print("Number of unique pathways:", drug_features["Target_Pathway"].nunique())

df_target_target_pathway = pd.concat([df_target, pd.get_dummies(drug_features["Target_Pathway"])], axis=1)
df_target_target_pathway.shape
# Out:
# Number of unique pathways: 25
# (297, 267)

# %%
df_target_target_pathway.to_csv("GDSC2_target_target_pathway_df.csv", index=False)

# %%
# only pathway
df_target_pathway = pd.get_dummies(drug_features["Target_Pathway"])
df_target_pathway
# Out:
#          -  ABL signaling  ...  WNT signaling  p53 pathway
# DRUG_ID                    ...
# 1834     0              0  ...              0            0
# 1854     0              0  ...              1            0
# 1909     0              0  ...              0            0
# 1913     0              0  ...              0            0
# 1915     0              0  ...              0            0
# ...     ..            ...  ...            ...          ...
# 2156     0              0  ...              0            0
# 2362     0              0  ...              0            0
# 1030     0              0  ...              0            0
# 1129     0              0  ...              0            0
# 1192     0              0  ...              0            0
#
# [297 rows x 25 columns]

# %%
df_target_pathway.to_csv('GDSC2_target_pathway_df.csv')

# %% [markdown]
# ### Write names of uniques Targets and Target_Pathway

# %%
with open("X_features_Targets.txt", 'w') as f:
    for s in targets:
        f.write(str(s) + '\n')
        
with open("X_features_Target_Pathway.txt", 'w') as f:
    for s in drug_features["Target_Pathway"].unique():
        f.write(str(s) + '\n')

# %%
df_target_target_pathway.reset_index()
# Out:
#      DRUG_ID  MTORC2  NAMPT  ...  Unclassified  WNT signaling  p53 pathway
# 0       1834       0      0  ...             1              0            0
# 1       1854       0      0  ...             0              1            0
# 2       1909       0      0  ...             0              0            0
# 3       1913       0      0  ...             0              0            0
# 4       1915       0      0  ...             0              0            0
# ..       ...     ...    ...  ...           ...            ...          ...
# 292     2156       0      0  ...             0              0            0
# 293     2362       0      0  ...             0              0            0
# 294     1030       0      0  ...             0              0            0
# 295     1129       0      0  ...             0              0            0
# 296     1192       0      0  ...             0              0            0
#
# [297 rows x 268 columns]

# %%
df_target_pathway.reset_index()
# Out:
#      DRUG_ID  -  ABL signaling  ...  Unclassified  WNT signaling  p53 pathway
# 0       1834  0              0  ...             1              0            0
# 1       1854  0              0  ...             0              1            0
# 2       1909  0              0  ...             0              0            0
# 3       1913  0              0  ...             0              0            0
# 4       1915  0              0  ...             0              0            0
# ..       ... ..            ...  ...           ...            ...          ...
# 292     2156  0              0  ...             0              0            0
# 293     2362  0              0  ...             0              0            0
# 294     1030  0              0  ...             0              0            0
# 295     1129  0              0  ...             0              0            0
# 296     1192  0              0  ...             0              0            0
#
# [297 rows x 26 columns]

# %%
with open("X_features_cancer_cell_lines.txt", 'r') as f:
    X_cancer_cell_lines = [line.rstrip('\n') for line in f]

# %%
print("Final Features: \n")
print("Cell lines (CCL) features:", len(X_cancer_cell_lines))
print("PubChem drug features:", len(PubChem_features))
print("Drug description features - Targets: %d, Target_Pathway: %d" % (len(targets), drug_features["Target_Pathway"].nunique()))
# Out:
# Final Features:
#
# Cell lines (CCL) features: 1073
# PubChem drug features: 26
# Drug description features - Targets: 242, Target_Pathway: 25

# %%
all_elements
# Out:
# ["'Pt'",
#  " 'Cl'",
#  " 'I'",
#  " 'O'",
#  " 'Br'",
#  "'N'",
#  " 'S'",
#  " 'F'",
#  "'B'",
#  " 'Pt'",
#  "'Br'",
#  "'H'",
#  " 'N'",
#  "'P'"]
