# %% [markdown]
# ## Merge with Drug Properties

# %% [markdown]
# Add preprocessed earlier drug description and characteristics

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")
import os

# %%
#df_profiles = pd.read_csv(_FOLDER+"GDSC2_merged_drug_profiles_cells_sigmoid4.csv")
df_profiles = pd.read_csv("GDSC2_merged_drug_profiles_cells_sigmoid4.csv")
df_drugs_properties = pd.read_csv("GDSC2_drug_features_with_pubchem_properties.csv")
df_targets = pd.read_csv("GDSC2_target_pathway_df.csv")


df_profiles.shape, df_drugs_properties.shape, df_targets.shape
# Out:
# ((342744, 1098), (297, 39), (297, 26))

# %%
df_profiles
# Out:
#        SCAN_DRUGID_COSMICID_KEY  ...  chr9:98783216-98784364(NCRNA00092)_HypMET
# 0           14769_1003_924100_0  ...                                          0
# 1           24662_1003_924100_0  ...                                          0
# 2           24663_1003_924100_0  ...                                          0
# 3           32860_1003_924100_0  ...                                          0
# 4           32861_1003_924100_0  ...                                          0
# ...                         ...  ...                                        ...
# 342739      49717_2111_908450_0  ...                                          1
# 342740      49717_2169_908450_0  ...                                          1
# 342741      49717_2170_908450_0  ...                                          1
# 342742      49717_2172_908450_0  ...                                          1
# 342743      49717_2177_908450_0  ...                                          1
#
# ...

# %%
df_targets
# Out:
#      DRUG_ID  -  ABL signaling  ...  Unclassified  WNT signaling  p53 pathway
# 0       1834  0              0  ...             1              0            0
# 1       1854  0              0  ...             0              1            0
# 2       1909  0              0  ...             0              0            0
# 3       1913  0              0  ...             0              0            0
# 4       1915  0              0  ...             0              0            0
# ..       ... ..            ...  ...           ...            ...          ...
# 292     2156  0              0  ...             0              0            0
# 293     2362  0              0  ...             0              0            0
# 294     1030  0              0  ...             0              0            0
# 295     1129  0              0  ...             0              0            0
# 296     1192  0              0  ...             0              0            0
#
# [297 rows x 26 columns]

# %%
df_drugs_properties.head(2)
# Out:
#    DRUG_ID Drug_Name        Target Target_Pathway  ...    O    F    H    I
# 0     1834    743380             -   Unclassified  ...  NaN  NaN  NaN  NaN
# 1     1854     MN-64  TNKS1, TNKS2  WNT signaling  ...  1.0  0.0  1.0  0.0
#
# [2 rows x 39 columns]

# %%
df_drugs_properties[df_drugs_properties["PubChem_ID"]=="0"]
# Out:
#      DRUG_ID              Drug_Name  ...   H   I
# 8       2011            ICL-SIRT078  ... NaN NaN
# 18      1584           BDOCA000347a  ... NaN NaN
# 25      1716             IRAK4_4710  ... NaN NaN
# 29      2360                THR-101  ... NaN NaN
# 36      1832                 729189  ... NaN NaN
# 54      1776            GSK2256098C  ... NaN NaN
# 55      1783                LMB_AB1  ... NaN NaN
# 58      2112                  VTP-A  ... NaN NaN
# 59      2149               CT7033-2  ... NaN NaN
# 65      1828                 720427  ... NaN NaN
# 67      1839                 615590  ... NaN NaN
# 76      2010            HKMTI-1-005  ... NaN NaN
# 87      1821                 765771  ... NaN NaN
# 88      1733              ULK1_4989  ... NaN NaN
# 89      1734             VSP34_8731  ... NaN NaN
# 91      1784                LMB_AB2  ... NaN NaN
# 105     1829                 667880  ... NaN NaN
# 107     1833                 741909  ... NaN NaN
# ...

# %% [markdown]
# ### Merge data

# %%
column_not_to_use = ["Synonyms", "deriv_found", "PubChem_ID",
                    "inchi_key", "canonical_smiles", "inchi_string"]
columns_to_use = set(df_drugs_properties.columns) - set(column_not_to_use)

len(set(columns_to_use))
# Out:
# 34

# %%
merged_df = pd.merge(left = df_profiles, right = df_drugs_properties[columns_to_use], on = "DRUG_ID")
merged_df = pd.merge(left = merged_df, right = df_targets, on = "DRUG_ID") 
merged_df
# Out:
#        SCAN_DRUGID_COSMICID_KEY  DRUG_ID  ...  WNT signaling  p53 pathway
# 0           14769_1003_924100_0     1003  ...              0            0
# 1           24662_1003_924100_0     1003  ...              0            0
# 2           24663_1003_924100_0     1003  ...              0            0
# 3           32860_1003_924100_0     1003  ...              0            0
# 4           32861_1003_924100_0     1003  ...              0            0
# ...                         ...      ...  ...            ...          ...
# 342739      42663_1243_930301_0     1243  ...              0            0
# 342740     42841_1243_1240224_0     1243  ...              0            0
# 342741     52754_1243_1303911_0     1243  ...              0            0
# 342742      41796_1243_908452_0     1243  ...              0            0
# 342743      50551_1243_908450_0     1243  ...              0            0
#
# [342744 rows x 1156 columns]

# %%
merged_df
# Out:
#        SCAN_DRUGID_COSMICID_KEY  DRUG_ID  ...  WNT signaling  p53 pathway
# 0           14769_1003_924100_0     1003  ...              0            0
# 1           24662_1003_924100_0     1003  ...              0            0
# 2           24663_1003_924100_0     1003  ...              0            0
# 3           32860_1003_924100_0     1003  ...              0            0
# 4           32861_1003_924100_0     1003  ...              0            0
# ...                         ...      ...  ...            ...          ...
# 342739      42663_1243_930301_0     1243  ...              0            0
# 342740     42841_1243_1240224_0     1243  ...              0            0
# 342741     52754_1243_1303911_0     1243  ...              0            0
# 342742      41796_1243_908452_0     1243  ...              0            0
# 342743      50551_1243_908450_0     1243  ...              0            0
#
# [342744 rows x 1156 columns]

# %%
# potential features for ML:
# - X_cancer_cell_lines - 1073
# - X_PubChem_properties - 26
# - X_targets - 229
# - X_target_pathway

with open("X_features_cancer_cell_lines.txt", 'r') as f:
    X_cancer_cell_lines = [line.rstrip('\n') for line in f]
print("Number of cancer cell lines features:", len(X_cancer_cell_lines))
# *****************************************

with open("X_PubChem_properties.txt", 'r') as f:
    X_PubChem_properties = [line.rstrip('\n') for line in f]
print("Number of PubChem drug properties:", len(X_PubChem_properties))
# *****************************************

#with open(_FOLDER+"X_features_Targets.txt", 'r') as f:
    #X_targets = [line.rstrip('\n') for line in f]
#print("Number of possible targets:", len(X_targets))
# *****************************************

with open(_FOLDER+"X_features_Target_Pathway.txt", 'r') as f:
    X_target_pathway = [line.rstrip('\n') for line in f]
print("Number of possible target pathways:", len(X_target_pathway))
# *****************************************

#print("\n Maximum number of features:",len(X_cancer_cell_lines)+ len(X_PubChem_properties)+len(X_targets) + len(X_target_pathway))
print("\n Maximum number of features:",len(X_cancer_cell_lines)+ len(X_PubChem_properties) + len(X_target_pathway))
# Out:
# Number of cancer cell lines features: 1073
# Number of PubChem drug properties: 26
# Number of possible target pathways: 25
#
#  Maximum number of features: 1124

# %%
#difference = set(merged_df_2.columns) - set(X_cancer_cell_lines + X_PubChem_properties + X_targets + X_target_pathway)
difference = set(merged_df.columns) - set(X_cancer_cell_lines + X_PubChem_properties + X_target_pathway)
len(difference), difference
# Out:
# (32,
#  {'COSMIC_ID',
#   'DRUG_ID',
#   'Drug_Name',
#   'FOLD_RANGE',
#   'H',
#   'MAX_CONC',
#   'PubChem',
#   'SCAN_DRUGID_COSMICID_KEY',
#   'Target',
#   'Target_Pathway',
#   'elements',
#   'fd_num_0',
#   'fd_num_1',
#   'fd_num_2',
#   'fd_num_3',
#   'fd_num_4',
#   'fd_num_5',
#   'fd_num_6',
#   'fd_num_7',
#   'molecular_formula',
#   'norm_cells_0',
#   'norm_cells_1',
#   'norm_cells_2',
#   'norm_cells_3',
#   'norm_cells_4',
#   'norm_cells_5',
#   'norm_cells_6',
#   'norm_cells_7',
#   'param_1',
#   'param_2',
#   'param_3',
#   'param_4'})

# %% [markdown]
# ### Exclude drugs that don't have PubChem_id

# %%
drugs_with_pubchem_id = df_drugs_properties[df_drugs_properties["PubChem_ID"]!="0"]["DRUG_ID"].values
drugs_with_no_pubchem_id = df_drugs_properties[df_drugs_properties["PubChem_ID"]=="0"]["DRUG_ID"].values

with open("GDSC2_drugs_with_pubchem_id.txt", 'w') as f:
    for s in drugs_with_pubchem_id:
        f.write(str(s) + '\n')
with open("GDSC2_drugs_with_no_pubchem_id.txt", 'w') as f:
    for s in drugs_with_no_pubchem_id:
        f.write(str(s) + '\n')
print("All drugs: %d, With known PubChem_Id: %d" % (df_drugs_properties.shape[0], len(drugs_with_pubchem_id)))
# Out:
# All drugs: 297, With known PubChem_Id: 244

# %%
filtered_drugs_with_pubchem_id = set(drugs_with_pubchem_id) & set(df_profiles["DRUG_ID"].unique())

merged_df_2 = merged_df.set_index("DRUG_ID").loc[filtered_drugs_with_pubchem_id, :].reset_index()
merged_df_2.shape
# Out:
# (307174, 1156)

# %%
merged_df_2
# Out:
#         DRUG_ID SCAN_DRUGID_COSMICID_KEY  ...  WNT signaling  p53 pathway
# 0          2048      24663_2048_924100_0  ...              0            0
# 1          2048      20137_2048_910924_0  ...              0            0
# 2          2048      19643_2048_687561_0  ...              0            0
# 3          2048     42063_2048_1287706_0  ...              0            0
# 4          2048      20483_2048_687452_0  ...              0            0
# ...         ...                      ...  ...            ...          ...
# 307169     1023      52829_1023_946358_0  ...              0            0
# 307170     1023      53331_1023_909907_0  ...              0            0
# 307171     1023     46344_1023_1298146_0  ...              0            0
# 307172     1023      41796_1023_908452_0  ...              0            0
# 307173     1023      50542_1023_908450_0  ...              0            0
#
# [307174 rows x 1156 columns]

# %% [markdown]
# ### Exclude drugs that don't have PubChem_id

# %%
drugs_with_pubchem_id = df_drugs_properties[df_drugs_properties["PubChem_ID"]!=0]["DRUG_ID"]
print("All drugs: %d, With known PubChem_Id: %d" % (df_drugs_properties.shape[0], len(drugs_with_pubchem_id)))
# Out:
# All drugs: 297, With known PubChem_Id: 297

# %%
drugs_with_pubchem_id = df_drugs_properties[df_drugs_properties["PubChem_ID"]!=0]["DRUG_ID"].values
merged_df_2 = merged_df_2.set_index("DRUG_ID").loc[filtered_drugs_with_pubchem_id, :].reset_index()
merged_df_2.shape
# Out:
# (307174, 1156)

# %%
merged_df_2
# Out:
#         DRUG_ID SCAN_DRUGID_COSMICID_KEY  ...  WNT signaling  p53 pathway
# 0          2048      24663_2048_924100_0  ...              0            0
# 1          2048      20137_2048_910924_0  ...              0            0
# 2          2048      19643_2048_687561_0  ...              0            0
# 3          2048     42063_2048_1287706_0  ...              0            0
# 4          2048      20483_2048_687452_0  ...              0            0
# ...         ...                      ...  ...            ...          ...
# 307169     1023      52829_1023_946358_0  ...              0            0
# 307170     1023      53331_1023_909907_0  ...              0            0
# 307171     1023     46344_1023_1298146_0  ...              0            0
# 307172     1023      41796_1023_908452_0  ...              0            0
# 307173     1023      50542_1023_908450_0  ...              0            0
#
# [307174 rows x 1156 columns]

# %% [markdown]
# ## Get rid of the NaN data

# %%
merged_df_filtna = merged_df_2.dropna()
merged_df_filtna
# Out:
#         DRUG_ID SCAN_DRUGID_COSMICID_KEY  ...  WNT signaling  p53 pathway
# 0          2048      24663_2048_924100_0  ...              0            0
# 1          2048      20137_2048_910924_0  ...              0            0
# 2          2048      19643_2048_687561_0  ...              0            0
# 3          2048     42063_2048_1287706_0  ...              0            0
# 4          2048      20483_2048_687452_0  ...              0            0
# ...         ...                      ...  ...            ...          ...
# 307169     1023      52829_1023_946358_0  ...              0            0
# 307170     1023      53331_1023_909907_0  ...              0            0
# 307171     1023     46344_1023_1298146_0  ...              0            0
# 307172     1023      41796_1023_908452_0  ...              0            0
# 307173     1023      50542_1023_908450_0  ...              0            0
#
# [288565 rows x 1156 columns]

# %%
merged_df_allnull = merged_df_2[merged_df_2.isnull().all(axis=1)]
merged_df_allnull
# Out:
# Empty DataFrame
# ...

# %%
merged_df_nan.to_csv("GDSC2_merged_fitted_sigmoid4_with_drugs_properties_NaN.csv", index=False)

# %% [markdown]
# ### Save the data

# %%
merged_df_2["Br"].value_counts()
# Out:
# 0.0    297453
# 1.0      7338
# Name: Br, dtype: int64

# %%
merged_df_2.isna().sum() #Double check if there are not NaN data (sum should be 0)
# Out:
# DRUG_ID                              0
# SCAN_DRUGID_COSMICID_KEY             0
# COSMIC_ID                            0
# FOLD_RANGE                           0
# MAX_CONC                             0
#                                     ..
# Protein stability and degradation    0
# RTK signaling                        0
# Unclassified                         0
# WNT signaling                        0
# p53 pathway                          0
# Length: 1156, dtype: int64

# %%
merged_df_2.to_csv("GDSC2_merged_fitted_sigmoid4_with_drugs_properties.csv", index=False)

# %%
merged_df_2.columns
# Out:
# Index(['DRUG_ID', 'SCAN_DRUGID_COSMICID_KEY', 'COSMIC_ID', 'FOLD_RANGE',
#        'MAX_CONC', 'fd_num_0', 'fd_num_1', 'fd_num_2', 'fd_num_3', 'fd_num_4',
#        ...
#        'Metabolism', 'Mitosis', 'Other', 'Other, kinases',
#        'PI3K/MTOR signaling', 'Protein stability and degradation',
#        'RTK signaling', 'Unclassified', 'WNT signaling', 'p53 pathway'],
#       dtype='object', length=1156)

# %%
#filter out drug properties
try:
    df = pd.read_csv("GDSC2_merged_fitted_sigmoid4_with_drugs_properties.csv").drop(['H', 'Target', 'Target_Pathway', 'elements'], axis = 1)
except:
    df = pd.read_csv("GDSC2_merged_fitted_sigmoid4_with_drugs_properties.csv").drop(['Target', 'Target_Pathway', 'elements'], axis = 1)

df.shape
# Out:
# (307174, 1152)

# %%
#previous (307030, 1152)
df
# Out:
#         DRUG_ID SCAN_DRUGID_COSMICID_KEY  ...  WNT signaling  p53 pathway
# 0          2048      24663_2048_924100_0  ...              0            0
# 1          2048      20137_2048_910924_0  ...              0            0
# 2          2048      19643_2048_687561_0  ...              0            0
# 3          2048     42063_2048_1287706_0  ...              0            0
# 4          2048      20483_2048_687452_0  ...              0            0
# ...         ...                      ...  ...            ...          ...
# 307169     1023      52829_1023_946358_0  ...              0            0
# 307170     1023      53331_1023_909907_0  ...              0            0
# 307171     1023     46344_1023_1298146_0  ...              0            0
# 307172     1023      41796_1023_908452_0  ...              0            0
# 307173     1023      50542_1023_908450_0  ...              0            0
#
# [307174 rows x 1152 columns]

# %%
df_features = pd.DataFrame({'feature':df.columns})
df_features
# Out:
#                                 feature
# 0                               DRUG_ID
# 1              SCAN_DRUGID_COSMICID_KEY
# 2                             COSMIC_ID
# 3                            FOLD_RANGE
# 4                              MAX_CONC
# ...                                 ...
# 1147  Protein stability and degradation
# 1148                      RTK signaling
# 1149                       Unclassified
# 1150                      WNT signaling
# 1151                        p53 pathway
#
# [1152 rows x 1 columns]

# %%
df_features.to_csv('GDSC2_df_features_col.csv', index=False)

# %%
#drop columns
merged_df_final = df.drop(['Drug_Name', 'PubChem', 'molecular_formula', 'Unclassified', 'Other', 'Other, kinases', '-'], axis = 1)
merged_df_final
# Out:
#         DRUG_ID SCAN_DRUGID_COSMICID_KEY  ...  WNT signaling  p53 pathway
# 0          2048      24663_2048_924100_0  ...              0            0
# 1          2048      20137_2048_910924_0  ...              0            0
# 2          2048      19643_2048_687561_0  ...              0            0
# 3          2048     42063_2048_1287706_0  ...              0            0
# 4          2048      20483_2048_687452_0  ...              0            0
# ...         ...                      ...  ...            ...          ...
# 307169     1023      52829_1023_946358_0  ...              0            0
# 307170     1023      53331_1023_909907_0  ...              0            0
# 307171     1023     46344_1023_1298146_0  ...              0            0
# 307172     1023      41796_1023_908452_0  ...              0            0
# 307173     1023      50542_1023_908450_0  ...              0            0
#
# [307174 rows x 1145 columns]

# %%
GDSC2_processed_features = pd.DataFrame({'feature':merged_df_final.columns})
GDSC2_processed_features
# Out:
#                                 feature
# 0                               DRUG_ID
# 1              SCAN_DRUGID_COSMICID_KEY
# 2                             COSMIC_ID
# 3                            FOLD_RANGE
# 4                              MAX_CONC
# ...                                 ...
# 1140                PI3K/MTOR signaling
# 1141  Protein stability and degradation
# 1142                      RTK signaling
# 1143                      WNT signaling
# 1144                        p53 pathway
#
# [1145 rows x 1 columns]

# %%
PubChem_features = ["molecular_weight","2bonds", "3bonds", "xlogp", "formal_charge", 
    "surface_area", "complexity", "h_bond_donor_count", 
    "h_bond_acceptor_count", "rotatable_bond_count",
    "heavy_atom_count", "atom_stereo_count", "defined_atom_stereo_count",
    "undefined_atom_stereo_count", "bond_stereo_count", "covalent_unit_count",
    'B', 'I', 'Br', 'Cl', 'O', 'N', 'F', 'P', 'S', 'Pt']

# %%
GDSC2_processed_features['specificity'] = pd.np.where(GDSC2_processed_features['feature'].str.contains("mut"),"cell_line",
                               pd.np.where(GDSC2_processed_features['feature'].str.contains("PANCAN"),"cell_line",
                               pd.np.where(GDSC2_processed_features['feature'].str.contains("HypMET"),"cell_line",
                               pd.np.where(GDSC2_processed_features['feature'].str.contains("subtype|DRUG_ID|COSMICID|COSMIC_ID|FOLD_RANGE|MAX_CONC|fd_num|norm_cells|param_", regex=True),"others", 
                               pd.np.where(GDSC2_processed_features['feature'].isin(PubChem_features),"drug","drug_pathway")))))
GDSC2_processed_features
# Out:
#                                 feature   specificity
# 0                               DRUG_ID        others
# 1              SCAN_DRUGID_COSMICID_KEY        others
# 2                             COSMIC_ID        others
# 3                            FOLD_RANGE        others
# 4                              MAX_CONC        others
# ...                                 ...           ...
# 1140                PI3K/MTOR signaling  drug_pathway
# 1141  Protein stability and degradation  drug_pathway
# 1142                      RTK signaling  drug_pathway
# 1143                      WNT signaling  drug_pathway
# 1144                        p53 pathway  drug_pathway
#
# [1145 rows x 2 columns]

# %%
GDSC2_processed_features.to_csv('GDSC2_features_col.csv', index=False)

# %%
# FINAL VERSION_2023
merged_df_final.to_csv('GDSC2_processed_dose_response.csv', index=False)
